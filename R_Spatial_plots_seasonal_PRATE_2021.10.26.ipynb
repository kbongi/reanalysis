# %% [markdown]
# # Plot spatial data for 20CR

# %%
import xarray as xr, matplotlib.pyplot as plt
from importlib import reload # need to use this if I edit a function file
import os
import numpy as np
import pandas as pd
import cartopy.crs as ccrs # to add in continents and change map projections 
from matplotlib.colors import LinearSegmentedColormap # to change colour bar????
import dask.diagnostics # dask allows you to check how long something is taking to load
import climtas # needed to count event statistics with a specified duration

# %%
# import custom functions
import sys 
sys.path.append('/g/data/w48/kb6999/Functions') # use this if the function file is in a different directory to the notebook

import frequently_used_functions as func
import plotting_functions as fplot
import model_functions as funcM
import reanalysis_functions as funcR

# %% [markdown]
# # 20CR data

# %%
# define path where netcdsf of temperature are stored
path = '/g/data/w48/kb6999/Reanalysis/20CR_PRATE_seasonal_data_for_plots/'

# %%
# open mmm of rainfall 
mmm_mon_Glob = xr.open_dataset(f'{path}mmm_anom_glob.nc')
mmm_mon_Glob
# Out:
# <xarray.Dataset>
# Dimensions:     (season: 4, lon: 512, lat: 256, seasonyear: 167)
# Coordinates:
#   * season      (season) object 'DJF' 'JJA' 'MAM' 'SON'
#   * lon         (lon) float64 0.0 0.7031 1.406 2.109 ... 357.2 357.9 358.6 359.3
#   * lat         (lat) float64 89.46 88.77 88.07 87.37 ... -88.07 -88.77 -89.46
#   * seasonyear  (seasonyear) int64 1850 1851 1852 1853 ... 2013 2014 2015 2016
# Data variables:
#     pr          (seasonyear, season, lat, lon) float64 ...

# %%
# select out dates around kraktoa eruption 
K_mmm_mon_Glob_r = mmm_mon_Glob.sel(seasonyear = slice('1850','1990'))

# %%
# reverse the latitude axis so it goes from -90 to 90
K_mmm_mon_Glob = K_mmm_mon_Glob_r.reindex(lat=list(reversed(K_mmm_mon_Glob_r.lat)))

# %%
# import landmask dataset 
landfrac_ds = xr.open_dataset('/g/data/w48/kb6999/Reanalysis/20CR_data_netcdfs/land_pr_20CR.nc')
landmask = landfrac_ds

# %%
# Select out SH and NH anomalies 
K_mmm_mon_SH = K_mmm_mon_Glob.sel(lat=slice(0,-90)) 
K_mmm_mon_NH = K_mmm_mon_Glob.sel(lat=slice(90,0)) 
# select out the Australian and E Australian anomalies 
K_mmm_mon_Aus = K_mmm_mon_Glob.sel(lat=slice(-50,-10), lon=slice(110,160)).where(landmask.LAND==1.0, drop=True)
K_mmm_mon_EA = K_mmm_mon_Glob.sel(lat=slice(-50,-5), lon=slice(140,155)).where(landmask.LAND==1.0, drop=True)

# %%
K_mmm_mon_Aus
# Out:
# <xarray.Dataset>
# Dimensions:     (seasonyear: 141, season: 4, lat: 44, lon: 57)
# Coordinates:
#   * lat         (lat) float64 -43.16 -42.46 -41.75 ... -12.28 -11.58 -10.18
#   * lon         (lon) float64 113.9 114.6 115.3 116.0 ... 151.9 152.6 153.3
#   * season      (season) object 'DJF' 'JJA' 'MAM' 'SON'
#   * seasonyear  (seasonyear) int64 1850 1851 1852 1853 ... 1987 1988 1989 1990
# Data variables:
#     pr          (seasonyear, season, lat, lon) float64 nan nan nan ... nan nan

# %% [markdown]
# ## Figures

# %%
# set the default font size
SMALL_SIZE = 10
MEDIUM_SIZE = 12
BIGGER_SIZE = 14

plt.rc('font', size=BIGGER_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
# dates and title for eruption and 3 times after
# K_dates winter
K_dates_w = [1883, 1884, 1885, 1886]
#K_dates_w = ['1883', '1884', '1885', '1886']
# K_dates_summer
K_dates_s = [1882, 1883, 1884, 1885]
#K_dates_s = ['1882', '1883', '1884', '1885']

# %%
# winter titles
titles_w = func.seasonal_title(K_dates_w, 'winter', 'JJA')
 # summer titles 
titles_s = func.seasonal_title(K_dates_s, 'summer', 'DJF')
titles_s
# Out:
# ['summer prior to eruption, DJF 1882',
#  '1st summer post-eruption, DJF 1883',
#  '2nd summer post-eruption, DJF 1884',
#  '3rd summer post-eruption, DJF 1885']

# %%
# define degree sign
deg = u'\N{DEGREE SIGN}'

# %%
# set the mod max for the colour bars
cmax_tmp = [-2,2]
cmax_pr = [-2,2]

# %%
# plot of global monthly member mean rainfall at 4 discrete time periods (not averaged)
fig = fplot.spatial_plot(2, 2, K_mmm_mon_Glob.pr.sel(season='JJA'), cmax_pr, K_dates_w, titles_w, 'BrBG', f'Precipitation anomaly [mm/day]', 1)

fig.set_figwidth(15)
fig.set_figheight(11) # these two parameters change the figure height and width 

plt.savefig('R_spatial_pr_JJA_Glob.pdf', dpi=300, bbox_inches='tight') # bbox=tight removes lat labels when figure saves

# %%
# plot of global monthly member mean rainfall at 4 discrete time periods (not averaged)
fig = fplot.spatial_plot(2, 2, K_mmm_mon_Glob.pr.sel(season='DJF'), cmax_pr, K_dates_w, titles_s, 'BrBG', f'Precipitation anomaly [mm/day]', 1)

fig.set_figwidth(15)
fig.set_figheight(11) # these two parameters change the figure height and width 

plt.savefig('R_spatial_pr_DJF_Glob.pdf', dpi=300, bbox_inches='tight') # bbox=tight removes lat labels when figure saves

# %%
# plot of Aus monthly member mean rainfall
fig = fplot.spatial_plot(2, 2, K_mmm_mon_Aus.pr.sel(season='JJA'), cmax_tmp, K_dates_w, titles_w, 'BrBG', f'Precipitation anomaly [mm/day]', 1)

fig.set_figwidth(12)
fig.set_figheight(14) # these two parameters change the figure height and width 

plt.savefig('R_spatial_pr_JJA_Aus.pdf', dpi=300, bbox_inches='tight')
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1670: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,

# %%
# plot of Aus monthly member mean rainfall
fig = fplot.spatial_plot(2, 2, K_mmm_mon_Aus.pr.sel(season='DJF'), cmax_tmp, K_dates_w, titles_s, 'BrBG', f'Precipitation anomaly [mm/day]', 1)

fig.set_figwidth(12)
fig.set_figheight(14) # these two parameters change the figure height and width 

plt.savefig('R_spatial_pr_DJF_Aus.pdf', dpi=300, bbox_inches='tight')
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1670: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,

# %%
titles_w_cv=[]
titles_s_cv=[]
for i,vals in enumerate(K_dates_w):
    t = 'winter (JJA)' + f' {K_dates_w[i]}'
    titles_w_cv.append(t)

for i,vals in enumerate(K_dates_w):
    t = 'summer (DJF)' + f' {K_dates_s[i]}'
    titles_s_cv.append(t)
titles_s_cv
# Out:
# ['summer (DJF) 1882',
#  'summer (DJF) 1883',
#  'summer (DJF) 1884',
#  'summer (DJF) 1885']

# %%
# plot of Aus monthly member mean temperature
label_loc=[20,-2.2]
fig = fplot.spatial_plot_cv(1, 4, K_mmm_mon_Aus.pr.sel(season='JJA'), cmax_pr, K_dates_w, titles_w_cv, 'BrBG', f'Precipitation anomaly [mm/day]', 1, label_loc)

fig.set_figwidth(18)
fig.set_figheight(6) # these two parameters change the figure height and width 

# fig.set_xlabels(None)

plt.savefig('R_spatial_pr_JJA_Aus_4x1.png', dpi=300, bbox_inches='tight')
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1670: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,

# %%
# plot of Aus monthly member mean temperature
label_loc=[20,-2.2]
fig = fplot.spatial_plot_cv(1, 4, K_mmm_mon_Aus.pr.sel(season='DJF'), cmax_pr, K_dates_w, titles_s_cv, 'BrBG', 'Precipitation anomaly [mm/day]', 1, label_loc)

fig.set_figwidth(18)
fig.set_figheight(6) # these two parameters change the figure height and width 

# fig.set_xlabels(None)

plt.savefig('R_spatial_pr_DJF_Aus_4x1.png', dpi=300, bbox_inches='tight')
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-21.07/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1670: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,

# %%
# # plot of Aus monthly member mean precipitation
# fig = fplot.spatial_plot(2, 2, K_mmm_mon_Aus.pr, cmax_pr, K_dates, titles, 'BrBG','Precipitation anomaly [mm/day]', 1)

# fig.set_figwidth(12)
# fig.set_figheight(14) # these two parameters change the figure height and width 

# plt.savefig('R_spatial_pr_Aus.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## standard deviation plots

# %%
# calculate std as calculated in the graphs
std_Glob = K_mmm_mon_Glob.pr.sel(seasonyear = slice('1850', '1881')).std(dim = ['seasonyear'])
std_Aus = K_mmm_mon_Aus.pr.sel(seasonyear = slice('1850', '1881')).std(dim = ['seasonyear'])
# Out:
# /g/data3/hh5/public/apps/miniconda3/envs/analysis3-21.04/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1670: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,

# %%
# select out jja and djf seasons and put into a list for plotting
std_Glob_data = [std_Glob.sel(season='JJA'), std_Glob.sel(season='DJF')]
std_Aus_data = [std_Aus.sel(season='JJA'), std_Aus.sel(season='DJF')]
dataset=[std_Glob.sel(season='JJA'), std_Glob.sel(season='DJF'), std_Aus.sel(season='JJA'), std_Aus.sel(season='DJF')]

# %%
titles_Aus = ['Australia, JJA 1850-1880','Australia, DJF 1850-1880']
titles_std = ['Global, JJA 1850-1880','Global, DJF 1850-1880', 'Australia, JJA 1850-1880','Australia, DJF 1850-1880']

# %%
fplot=reload(fplot)

# %%
# plot of Global standard deviation
cmax_std = [0,1]
label_loc = [4.8, 0.15]
fig = fplot.std_plot(1, 2, std_Glob_data, cmax_std, titles_std, 'OrRd', f'Standard Deviation [{deg}C]', label_loc)

fig.set_figwidth(15)
fig.set_figheight(7) # these two parameters change the figure height and width 

plt.savefig('R_spatial_std_pr_Glob.pdf', dpi=300, bbox_inches='tight')

# %%
# plot of aus standard deviation
cmax_std = [0,1]
label_loc = [4.5, 0.15]
fig = fplot.std_plot(1, 2, std_Aus_data, cmax_std, titles_Aus, 'OrRd', f'Standard Deviation [{deg}C]', label_loc)

fig.set_figwidth(12)
fig.set_figheight(7) # these two parameters change the figure height and width 

plt.savefig('R_spatial_std_pr_Aus.pdf', dpi=300, bbox_inches='tight')
